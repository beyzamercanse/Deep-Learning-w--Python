# %% [markdown]
# #  Softmax

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.8.0-cp39-cp39-macosx_10_12_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy<2,>=1.21 in /Users/beyzamercan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.26.0)
# Collecting pillow>=6.2.0
#   Downloading Pillow-10.0.1-cp39-cp39-macosx_10_10_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 13.4 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.43.1-cp39-cp39-macosx_10_9_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 14.1 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/beyzamercan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (23.0)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.1.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/beyzamercan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.8.2)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp39-cp39-macosx_10_9_x86_64.whl (247 kB)
#      |████████████████████████████████| 247 kB 13.7 MB/s eta 0:00:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 14.9 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_10_9_x86_64.whl (68 kB)
#      |████████████████████████████████| 68 kB 9.2 MB/s  eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting zipp>=3.1.0
#   Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: zipp, pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.43.1 importlib-resources-6.1.0 kiwisolver-1.4.5 matplotlib-3.8.0 pillow-10.0.1 pyparsing-3.1.1 zipp-3.17.0
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries
import numpy as np
import torch
import torch.nn as nn       #neural networks
import matplotlib.pyplot as plt

# %%
# "manually" in numpy

# the list of numbers
z = [1,2,3]

# compute the softmax result
num = np.exp(z) #exponent
den = np.sum( np.exp(z) ) 
sigma = num / den

print(sigma)
print(np.sum(sigma))
# Out:
# [0.09003057 0.24472847 0.66524096]
# 1.0

# %%
# repeat with some random integers
z = np.random.randint(-5,high=15,size=25)
print(z)

# compute the softmax result
num = np.exp(z)
den = np.sum( num )
sigma = num / den

# compare
plt.plot(z,sigma,'ko')
plt.xlabel('Original number (z)')
plt.ylabel('Softmaxified $\sigma$')
plt.yscale('log')
plt.title('$\sum\sigma$ = %g' %np.sum(sigma))
plt.show()
# Out:
# [ 3 14  9 13  5  3 13 -5 14 -4 -5 -5 14 -4 -1 10  5  8 -1 -3  3  7 -1  1
#  -1]

# %% [markdown]
# # Using pytorch

# %%
# slightly more involved using torch.nn

# create an instance of the softmax activation class
softfun = nn.Softmax(dim=0)

# then apply the data to that function
sigmaT = softfun( torch.Tensor(z) )

# now we get the results
print(sigmaT)
# Out:
# tensor([4.4366e-06, 2.6564e-01, 1.7899e-03, 9.7723e-02, 3.2782e-05, 4.4366e-06,
#         9.7723e-02, 1.4883e-09, 2.6564e-01, 4.0457e-09, 1.4883e-09, 1.4883e-09,
#         2.6564e-01, 4.0457e-09, 8.1260e-08, 4.8654e-03, 3.2782e-05, 6.5845e-04,
#         8.1260e-08, 1.0997e-08, 4.4366e-06, 2.4223e-04, 8.1260e-08, 6.0043e-07,
#         8.1260e-08])

# %%
type(torch.Tensor(z))
# Out:
# torch.Tensor

# %%
# show that they are the same
plt.plot(sigma,sigmaT,'ko')
plt.xlabel('"Manual" softmax')
plt.ylabel('Pytorch nn.Softmax')
plt.title(f'The two methods correlate at r={np.corrcoef(sigma,sigmaT)[0,1]}')
plt.show()
